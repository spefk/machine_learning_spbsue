# %% [markdown]
# # <center> 4. Association Rules

# %% [markdown]
# - Association rules functions
# - Evaluation example

# %%
import numpy as np
import pandas as pd
from collections import Counter

# %%
##### Jupyter notebook theme setup:
# !pip install jupyterthemes
# !jt -t gruvboxd -fs 95 -tfs 11 -nfs 115 -cellw 80% -T
##### Reset theme:
# !jt -r
##### Plot style:
from jupyterthemes import jtplot
jtplot.style()

# Reload page after cell evaluation

# %% [markdown]
# # Data Import

# %%
df = pd.read_csv('data/store_data.csv', header=None)

# %%
df = df.apply(lambda x: list(set(x.dropna().tolist())), axis=1)\
    .to_frame('items')\
    .explode('items')\
    .set_index('items', append=True)\
    .assign(value=1)\
    .unstack()
df.columns = df.columns.droplevel(0)

# %%
# Creating DF of 0-es and 1-es.
one_zero_df = df.fillna(0)
one_zero_df.mean(axis=0).sort_values().tail(10)
# Out:
# items
# pancakes             0.095054
# frozen vegetables    0.095321
# ground beef          0.098254
# milk                 0.129583
# green tea            0.132116
# chocolate            0.163845
# french fries         0.170911
# spaghetti            0.174110
# eggs                 0.179709
# mineral water        0.238368
# dtype: float64

# %% [markdown]
# # Apriori algorithm

# %% [markdown]
# ### Functions

# %%
# Support
def support(df: pd.DataFrame, A_list: list) -> float:
    return df[A_list].all(axis=1).mean()

# Confidence
def confidence(df: pd.DataFrame, A_list: list, B_list: list) -> float:
    return support(df, A_list + B_list) / support(df, A_list)

# Lift definer
def lift(df: pd.DataFrame, A_list: list, B_list: list) -> float:
    return confidence(df, A_list, B_list) / support(df, B_list)

# %%
# K initialization
# One-product bins
def initialize_sets(df: pd.DataFrame, products, t: float) -> frozenset:
    return frozenset(([frozenset([p]) for p in products if support(df, [p]) > t]))

# %%
# One step of sets generation adding one element
def step_sets(df: pd.DataFrame, sets: frozenset, t: float) -> frozenset:
    survived_products = frozenset().union(*sets)
    out_set = set()
    for s in sets:
        for prod in survived_products.difference(s):
            out_set.add(s.union([prod]))
    return frozenset(filter(lambda x: support(df, x) > t, out_set))

# %%
# Lift checker
def lift_satisf(df: pd.DataFrame, sets: frozenset, a: float, products: frozenset) -> set:
    out_rules = set()
    for s in sets:
        for prod in products.difference(s):
            if lift(df, list(s), [prod]) > a:
                out_rules.add(((s, prod), '{0} => {1}'.format(list(s), prod)))
    return out_rules

# %%
# Algorithm realization
def apriori_algorithm(df: pd.DataFrame, t: float, a: float, products: frozenset) -> set:
    K = initialize_sets(df, products, t=t)
    rules = set()
    for _ in range(2, len(K)):
        K = step_sets(df, K, t=t)
        if K is frozenset():
            break
        rules = rules.union(lift_satisf(df, K, a=a, products=products))
    return tuple(rules)

# %% [markdown]
# ### Constants

# %%
t = 0.025 # Support threshold
a = 1.5    # Lift threshold
products = frozenset(one_zero_df.columns) # frozenset of all products

# %% [markdown]
# ### Test

# %%
for x in [
        support(one_zero_df, ['avocado', 'almonds', 'milk']),
        confidence(one_zero_df, ['avocado','almonds'], ['milk']),
        lift(one_zero_df, ['avocado','almonds'], ['milk']),
    ]:
    print(x)
# Out:
# 0.0005332622317024396
# 0.3076923076923077
# 2.374485596707819

# %%
result = apriori_algorithm(one_zero_df, t=t, a=a, products=products)
for i, (x, y) in enumerate(result):
    print ('rule {0}: {1}'.format(i, y))
# Out:
# rule 0: ['frozen vegetables', 'mineral water'] => asparagus
# rule 1: ['pancakes', 'spaghetti'] => rice
# rule 2: ['mineral water', 'milk'] => meatballs
# rule 3: ['pancakes', 'spaghetti'] => milk
# rule 4: ['spaghetti', 'chocolate'] => salmon
# rule 5: ['spaghetti', 'eggs'] => bacon
# rule 6: ['chocolate', 'milk'] => chicken
# rule 7: ['mineral water', 'chocolate'] => chicken
# rule 8: ['spaghetti', 'mineral water'] => tea
# rule 9: ['spaghetti', 'mineral water'] => herb & pepper
# rule 10: ['spaghetti', 'ground beef'] => hot dogs
# rule 11: ['spaghetti', 'mineral water'] => tomato sauce
# rule 12: ['spaghetti', 'milk'] => asparagus
# rule 13: ['mineral water', 'eggs'] => mayonnaise
# rule 14: ['olive oil', 'mineral water'] => ham
# rule 15: ['french fries', 'mineral water'] => tomato sauce
# rule 16: ['spaghetti', 'eggs'] => fresh tuna
# rule 17: ['spaghetti', 'mineral water'] => protein bar
# rule 18: ['pancakes', 'mineral water'] => grated cheese
# rule 19: ['french fries', 'chocolate'] => oatmeal
# rule 20: ['olive oil', 'mineral water'] => meatballs
# rule 21: ['pancakes', 'mineral water'] => brownies
# rule 22: ['french fries', 'mineral water'] => asparagus
# rule 23: ['mineral water', 'milk'] => pancakes
# rule 24: ['mineral water', 'eggs'] => burgers
# rule 25: ['spaghetti', 'mineral water'] => olive oil
# rule 26: ['frozen vegetables', 'mineral water'] => soup
# rule 27: ['french fries', 'green tea'] => hot dogs
# rule 28: ['mineral water', 'chocolate'] => ground beef
# rule 29: ['spaghetti', 'ground beef'] => green beans
# rule 30: ['green tea', 'eggs'] => tomato juice
# rule 31: ['mineral water', 'cake'] => fromage blanc
# rule 32: ['spaghetti', 'green tea'] => chili
# rule 33: ['mineral water', 'eggs'] => grated cheese
# rule 34: ['spaghetti', 'milk'] => nonfat milk
# rule 35: ['frozen vegetables', 'mineral water'] => muffins
# rule 36: ['mineral water', 'cake'] => brownies
# rule 37: ['mineral water', 'green tea'] => cider
# rule 38: ['mineral water', 'green tea'] => frozen smoothie
# rule 39: ['mineral water', 'green tea'] => cereals
# rule 40: ['spaghetti', 'frozen vegetables'] => cereals
# rule 41: ['mineral water', 'chocolate'] => french wine
# rule 42: ['spaghetti', 'french fries'] => chili
# rule 43: ['french fries', 'green tea'] => green beans
# rule 44: ['spaghetti', 'green tea'] => blueberries
# rule 45: ['spaghetti', 'french fries'] => escalope
# rule 46: ['pancakes', 'mineral water'] => ground beef
# rule 47: ['spaghetti', 'french fries'] => ground beef
# rule 48: ['mineral water', 'eggs'] => chicken
# rule 49: ['spaghetti', 'frozen vegetables'] => corn
# rule 50: ['french fries', 'chocolate'] => spinach
# rule 51: ['mineral water', 'milk'] => soda
# rule 52: ['chocolate', 'eggs'] => milk
# rule 53: ['french fries', 'chocolate'] => mashed potato
# rule 54: ['olive oil', 'mineral water'] => protein bar
# rule 55: ['spaghetti', 'french fries'] => pancakes
# rule 56: ['mineral water', 'ground beef'] => light cream
# rule 57: ['spaghetti', 'french fries'] => avocado
# rule 58: ['mineral water', 'ground beef'] => asparagus
# rule 59: ['spaghetti', 'mineral water'] => clothes accessories
# rule 60: ['burgers', 'eggs'] => babies food
# rule 61: ['pancakes', 'spaghetti'] => honey
# rule 62: ['pancakes', 'spaghetti'] => tea
# rule 63: ['pancakes', 'spaghetti'] => mayonnaise
# rule 64: ['pancakes', 'mineral water'] => gluten free bar
# rule 65: ['spaghetti', 'frozen vegetables'] => vegetables mix
# rule 66: ['frozen vegetables', 'mineral water'] => fresh bread
# rule 67: ['green tea', 'eggs'] => flax seed
# rule 68: ['green tea', 'eggs'] => mushroom cream sauce
# rule 69: ['spaghetti', 'frozen vegetables'] => hot dogs
# rule 70: ['mineral water', 'ground beef'] => oatmeal
# rule 71: ['spaghetti', 'french fries'] => fromage blanc
# rule 72: ['pancakes', 'spaghetti'] => cider
# rule 73: ['pancakes', 'spaghetti'] => cereals
# rule 74: ['french fries', 'chocolate'] => tomato sauce
# rule 75: ['mineral water', 'ground beef'] => pancakes
# rule 76: ['chocolate', 'eggs'] => flax seed
# rule 77: ['spaghetti', 'frozen vegetables'] => mint green tea
# rule 78: ['french fries', 'chocolate'] => ham
# rule 79: ['chocolate', 'milk'] => corn
# rule 80: ['spaghetti', 'frozen vegetables'] => protein bar
# rule 81: ['pancakes', 'spaghetti'] => extra dark chocolate
# rule 82: ['spaghetti', 'chocolate'] => sandwich
# rule 83: ['pancakes', 'mineral water'] => milk
# rule 84: ['mineral water', 'eggs'] => fresh tuna
# rule 85: ['mineral water', 'ground beef'] => brownies
# rule 86: ['spaghetti', 'french fries'] => zucchini
# rule 87: ['french fries', 'mineral water'] => chicken
# rule 88: ['spaghetti', 'frozen vegetables'] => herb & pepper
# rule 89: ['spaghetti', 'french fries'] => butter
# rule 90: ['olive oil', 'mineral water'] => chocolate bread
# rule 91: ['spaghetti', 'milk'] => extra dark chocolate
# rule 92: ['french fries', 'eggs'] => almonds
# rule 93: ['mineral water', 'ground beef'] => melons
# rule 94: ['spaghetti', 'green tea'] => pasta
# rule 95: ['spaghetti', 'chocolate'] => green beans
# rule 96: ['olive oil', 'mineral water'] => yams
# rule 97: ['milk', 'eggs'] => energy bar
# rule 98: ['spaghetti', 'green tea'] => almonds
# rule 99: ['spaghetti', 'chocolate'] => almonds
# rule 100: ['spaghetti', 'french fries'] => mushroom cream sauce
# rule 101: ['french fries', 'mineral water'] => gums
# rule 102: ['mineral water', 'milk'] => cream
# rule 103: ['mineral water', 'chocolate'] => blueberries
# rule 104: ['spaghetti', 'milk'] => olive oil
# rule 105: ['french fries', 'mineral water'] => cereals
# rule 106: ['pancakes', 'mineral water'] => tomato juice
# rule 107: ['spaghetti', 'eggs'] => cooking oil
# rule 108: ['spaghetti', 'green tea'] => pet food
# rule 109: ['milk', 'eggs'] => barbecue sauce
# rule 110: ['french fries', 'eggs'] => cake
# rule 111: ['spaghetti', 'green tea'] => frozen vegetables
# rule 112: ['spaghetti', 'frozen vegetables'] => french wine
# rule 113: ['spaghetti', 'frozen vegetables'] => parmesan cheese
# rule 114: ['olive oil', 'mineral water'] => fresh bread
# rule 115: ['mineral water', 'ground beef'] => barbecue sauce
# rule 116: ['spaghetti', 'milk'] => cooking oil
# rule 117: ['mineral water', 'eggs'] => salmon
# rule 118: ['mineral water', 'milk'] => magazines
# rule 119: ['frozen vegetables', 'mineral water'] => strong cheese
# rule 120: ['spaghetti', 'frozen vegetables'] => fresh bread
# rule 121: ['spaghetti', 'ground beef'] => pepper
# rule 122: ['spaghetti', 'frozen vegetables'] => green grapes
# rule 123: ['frozen vegetables', 'mineral water'] => whole weat flour
# rule 124: ['spaghetti', 'frozen vegetables'] => mint
# rule 125: ['spaghetti', 'chocolate'] => mint
# rule 126: ['mineral water', 'ground beef'] => red wine
# rule 127: ['spaghetti', 'eggs'] => gluten free bar
# rule 128: ['spaghetti', 'chocolate'] => burgers
# rule 129: ['frozen vegetables', 'mineral water'] => mayonnaise
# rule 130: ['spaghetti', 'eggs'] => tomato sauce
# rule 131: ['french fries', 'mineral water'] => ketchup
# rule 132: ['spaghetti', 'eggs'] => blueberries
# rule 133: ['mineral water', 'eggs'] => rice
# rule 134: ['olive oil', 'mineral water'] => flax seed
# rule 135: ['spaghetti', 'french fries'] => ketchup
# rule 136: ['spaghetti', 'french fries'] => muffins
# rule 137: ['spaghetti', 'green tea'] => bramble
# rule 138: ['pancakes', 'mineral water'] => whole weat flour
# rule 139: ['chocolate', 'eggs'] => black tea
# rule 140: ['french fries', 'chocolate'] => muffins
# rule 141: ['spaghetti', 'green tea'] => white wine
# rule 142: ['chocolate', 'eggs'] => mushroom cream sauce
# rule 143: ['french fries', 'green tea'] => magazines
# rule 144: ['chocolate', 'eggs'] => salmon
# rule 145: ['spaghetti', 'chocolate'] => gums
# rule 146: ['chocolate', 'milk'] => strong cheese
# rule 147: ['burgers', 'eggs'] => mint green tea
# rule 148: ['french fries', 'green tea'] => gums
# rule 149: ['spaghetti', 'frozen vegetables'] => muffins
# rule 150: ['spaghetti', 'ground beef'] => olive oil
# rule 151: ['spaghetti', 'ground beef'] => chili
# rule 152: ['mineral water', 'cake'] => avocado
# rule 153: ['spaghetti', 'milk'] => grated cheese
# rule 154: ['green tea', 'eggs'] => yogurt cake
# rule 155: ['french fries', 'mineral water'] => cream
# rule 156: ['mineral water', 'chocolate'] => carrots
# rule 157: ['olive oil', 'mineral water'] => salmon
# rule 158: ['mineral water', 'ground beef'] => milk
# rule 159: ['spaghetti', 'green tea'] => ham
# rule 160: ['spaghetti', 'french fries'] => gluten free bar
# rule 161: ['mineral water', 'eggs'] => carrots
# rule 162: ['frozen vegetables', 'mineral water'] => low fat yogurt
# rule 163: ['mineral water', 'milk'] => mint
# rule 164: ['mineral water', 'cake'] => meatballs
# rule 165: ['milk', 'eggs'] => brownies
# rule 166: ['pancakes', 'spaghetti'] => gums
# rule 167: ['spaghetti', 'ground beef'] => frozen vegetables
# rule 168: ['spaghetti', 'frozen vegetables'] => magazines
# rule 169: ['spaghetti', 'french fries'] => salmon
# rule 170: ['french fries', 'green tea'] => pickles
# rule 171: ['chocolate', 'eggs'] => pepper
# rule 172: ['pancakes', 'spaghetti'] => almonds
# rule 173: ['spaghetti', 'milk'] => chutney
# rule 174: ['french fries', 'chocolate'] => cooking oil
# rule 175: ['spaghetti', 'chocolate'] => vegetables mix
# rule 176: ['green tea', 'eggs'] => bug spray
# rule 177: ['mineral water', 'cake'] => burgers
# rule 178: ['milk', 'eggs'] => magazines
# rule 179: ['mineral water', 'green tea'] => frozen vegetables
# rule 180: ['mineral water', 'chocolate'] => frozen vegetables
# rule 181: ['olive oil', 'mineral water'] => green beans
# rule 182: ['spaghetti', 'eggs'] => burger sauce
# rule 183: ['chocolate', 'milk'] => whole wheat rice
# rule 184: ['mineral water', 'eggs'] => pasta
# rule 185: ['chocolate', 'milk'] => cauliflower
# rule 186: ['spaghetti', 'frozen vegetables'] => chutney
# rule 187: ['spaghetti', 'ground beef'] => grated cheese
# rule 188: ['milk', 'eggs'] => nonfat milk
# rule 189: ['mineral water', 'eggs'] => blueberries
# rule 190: ['milk', 'eggs'] => mint
# rule 191: ['mineral water', 'cake'] => asparagus
# rule 192: ['french fries', 'mineral water'] => fromage blanc
# rule 193: ['pancakes', 'spaghetti'] => mint
# rule 194: ['mineral water', 'cake'] => magazines
# rule 195: ['burgers', 'eggs'] => french wine
# rule 196: ['spaghetti', 'eggs'] => eggplant
# rule 197: ['pancakes', 'spaghetti'] => whole weat flour
# rule 198: ['french fries', 'green tea'] => avocado
# rule 199: ['mineral water', 'cake'] => light cream
# rule 200: ['mineral water', 'ground beef'] => shrimp
# rule 201: ['french fries', 'mineral water'] => clothes accessories
# rule 202: ['spaghetti', 'chocolate'] => pepper
# rule 203: ['spaghetti', 'french fries'] => rice
# rule 204: ['spaghetti', 'green tea'] => hot dogs
# rule 205: ['milk', 'eggs'] => carrots
# rule 206: ['spaghetti', 'mineral water'] => almonds
# rule 207: ['pancakes', 'spaghetti'] => salt
# rule 208: ['spaghetti', 'eggs'] => parmesan cheese
# rule 209: ['pancakes', 'mineral water'] => corn
# rule 210: ['pancakes', 'spaghetti'] => oatmeal
# rule 211: ['chocolate', 'milk'] => asparagus
# rule 212: ['spaghetti', 'mineral water'] => bacon
# rule 213: ['pancakes', 'spaghetti'] => frozen vegetables
# rule 214: ['spaghetti', 'green tea'] => light cream
# rule 215: ['spaghetti', 'milk'] => energy bar
# rule 216: ['pancakes', 'spaghetti'] => vegetables mix
# rule 217: ['french fries', 'green tea'] => light mayo
# rule 218: ['mineral water', 'green tea'] => white wine
# rule 219: ['pancakes', 'mineral water'] => light cream
# rule 220: ['mineral water', 'milk'] => green beans
# rule 221: ['spaghetti', 'frozen vegetables'] => shampoo
# rule 222: ['spaghetti', 'eggs'] => fresh bread
# rule 223: ['pancakes', 'mineral water'] => cottage cheese
# rule 224: ['spaghetti', 'french fries'] => toothpaste
# rule 225: ['french fries', 'green tea'] => salt
# rule 226: ['spaghetti', 'chocolate'] => chutney
# rule 227: ['spaghetti', 'green tea'] => soda
# rule 228: ['spaghetti', 'frozen vegetables'] => salmon
# rule 229: ['frozen vegetables', 'mineral water'] => tea
# rule 230: ['frozen vegetables', 'mineral water'] => ground beef
# rule 231: ['pancakes', 'spaghetti'] => chocolate
# rule 232: ['milk', 'eggs'] => french wine
# rule 233: ['spaghetti', 'chocolate'] => mushroom cream sauce
# rule 234: ['pancakes', 'spaghetti'] => cooking oil
# rule 235: ['mineral water', 'cake'] => mint green tea
# rule 236: ['spaghetti', 'mineral water'] => milk
# rule 237: ['pancakes', 'mineral water'] => dessert wine
# rule 238: ['mineral water', 'eggs'] => cauliflower
# rule 239: ['spaghetti', 'chocolate'] => fresh tuna
# rule 240: ['chocolate', 'eggs'] => oatmeal
# rule 241: ['chocolate', 'milk'] => burgers
# rule 242: ['spaghetti', 'green tea'] => toothpaste
# rule 243: ['french fries', 'green tea'] => barbecue sauce
# rule 244: ['spaghetti', 'milk'] => soda
# rule 245: ['green tea', 'eggs'] => black tea
# rule 246: ['olive oil', 'mineral water'] => chocolate
# rule 247: ['spaghetti', 'french fries'] => gums
# rule 248: ['mineral water', 'milk'] => vegetables mix
# rule 249: ['spaghetti', 'green tea'] => burgers
# rule 250: ['burgers', 'eggs'] => body spray
# rule 251: ['mineral water', 'ground beef'] => spaghetti
# rule 252: ['mineral water', 'chocolate'] => sparkling water
# rule 253: ['french fries', 'green tea'] => cottage cheese
# rule 254: ['french fries', 'eggs'] => brownies
# rule 255: ['french fries', 'mineral water'] => meatballs
# rule 256: ['mineral water', 'green tea'] => fresh tuna
# rule 257: ['milk', 'eggs'] => fromage blanc
# rule 258: ['spaghetti', 'french fries'] => cake
# rule 259: ['green tea', 'eggs'] => butter
# rule 260: ['spaghetti', 'french fries'] => whole wheat pasta
# rule 261: ['spaghetti', 'chocolate'] => olive oil
# rule 262: ['french fries', 'chocolate'] => burgers
# rule 263: ['french fries', 'mineral water'] => chocolate bread
# rule 264: ['spaghetti', 'french fries'] => grated cheese
# rule 265: ['mineral water', 'ground beef'] => blueberries
# rule 266: ['mineral water', 'eggs'] => low fat yogurt
# rule 267: ['spaghetti', 'eggs'] => frozen vegetables
# rule 268: ['spaghetti', 'ground beef'] => mint green tea
# rule 269: ['chocolate', 'milk'] => black tea
# rule 270: ['spaghetti', 'chocolate'] => whole wheat pasta
# rule 271: ['french fries', 'chocolate'] => escalope
# rule 272: ['spaghetti', 'milk'] => bramble
# rule 273: ['pancakes', 'mineral water'] => low fat yogurt
# rule 274: ['spaghetti', 'green tea'] => gluten free bar
# rule 275: ['french fries', 'mineral water'] => oil
# rule 276: ['olive oil', 'mineral water'] => mint
# rule 277: ['spaghetti', 'chocolate'] => cake
# rule 278: ['french fries', 'chocolate'] => gluten free bar
# rule 279: ['chocolate', 'milk'] => flax seed
# rule 280: ['milk', 'eggs'] => meatballs
# rule 281: ['spaghetti', 'mineral water'] => shampoo
# rule 282: ['mineral water', 'green tea'] => tomato juice
# rule 283: ['pancakes', 'spaghetti'] => frozen smoothie
# rule 284: ['frozen vegetables', 'mineral water'] => fromage blanc
# rule 285: ['spaghetti', 'milk'] => meatballs
# rule 286: ['pancakes', 'mineral water'] => burger sauce
# rule 287: ['french fries', 'green tea'] => butter
# rule 288: ['milk', 'eggs'] => burger sauce
# rule 289: ['spaghetti', 'chocolate'] => fromage blanc
# rule 290: ['mineral water', 'milk'] => fresh tuna
# rule 291: ['mineral water', 'green tea'] => cooking oil
# rule 292: ['spaghetti', 'frozen vegetables'] => butter
# rule 293: ['mineral water', 'eggs'] => cake
# rule 294: ['spaghetti', 'french fries'] => chicken
# rule 295: ['mineral water', 'green tea'] => magazines
# rule 296: ['burgers', 'eggs'] => barbecue sauce
# rule 297: ['milk', 'eggs'] => ground beef
# rule 298: ['spaghetti', 'mineral water'] => pet food
# rule 299: ['french fries', 'mineral water'] => bramble
# rule 300: ['spaghetti', 'mineral water'] => body spray
# rule 301: ['spaghetti', 'green tea'] => whole wheat pasta
# rule 302: ['burgers', 'eggs'] => blueberries
# rule 303: ['spaghetti', 'french fries'] => antioxydant juice
# rule 304: ['spaghetti', 'eggs'] => ground beef
# rule 305: ['french fries', 'chocolate'] => pancakes
# rule 306: ['frozen vegetables', 'mineral water'] => burgers
# rule 307: ['frozen vegetables', 'mineral water'] => french wine
# rule 308: ['french fries', 'mineral water'] => hand protein bar
# rule 309: ['french fries', 'green tea'] => carrots
# rule 310: ['mineral water', 'chocolate'] => chili
# rule 311: ['spaghetti', 'mineral water'] => gums
# rule 312: ['pancakes', 'spaghetti'] => mineral water
# rule 313: ['mineral water', 'milk'] => chocolate
# rule 314: ['mineral water', 'chocolate'] => mashed potato
# rule 315: ['spaghetti', 'milk'] => parmesan cheese
# rule 316: ['green tea', 'eggs'] => french wine
# rule 317: ['spaghetti', 'mineral water'] => french wine
# rule 318: ['pancakes', 'spaghetti'] => hand protein bar
# rule 319: ['spaghetti', 'chocolate'] => strong cheese
# rule 320: ['pancakes', 'spaghetti'] => body spray
# rule 321: ['french fries', 'eggs'] => green grapes
# rule 322: ['spaghetti', 'frozen vegetables'] => honey
# rule 323: ['spaghetti', 'green tea'] => burger sauce
# rule 324: ['mineral water', 'green tea'] => cauliflower
# rule 325: ['milk', 'eggs'] => chutney
# rule 326: ['spaghetti', 'french fries'] => oatmeal
# rule 327: ['mineral water', 'green tea'] => barbecue sauce
# rule 328: ['burgers', 'eggs'] => bramble
# rule 329: ['olive oil', 'mineral water'] => burger sauce
# rule 330: ['mineral water', 'chocolate'] => rice
# rule 331: ['chocolate', 'milk'] => tomatoes
# rule 332: ['spaghetti', 'frozen vegetables'] => cauliflower
# rule 333: ['mineral water', 'green tea'] => hot dogs
# rule 334: ['mineral water', 'milk'] => whole wheat pasta
# rule 335: ['mineral water', 'green tea'] => cake
# rule 336: ['spaghetti', 'mineral water'] => hand protein bar
# rule 337: ['mineral water', 'milk'] => almonds
# rule 338: ['chocolate', 'milk'] => fresh tuna
# rule 339: ['spaghetti', 'mineral water'] => zucchini
# rule 340: ['milk', 'eggs'] => cauliflower
# rule 341: ['mineral water', 'cake'] => yams
# rule 342: ['spaghetti', 'chocolate'] => chicken
# rule 343: ['pancakes', 'spaghetti'] => soup
# rule 344: ['french fries', 'mineral water'] => whole weat flour
# rule 345: ['mineral water', 'cake'] => frozen smoothie
# rule 346: ['mineral water', 'milk'] => chicken
# rule 347: ['chocolate', 'eggs'] => frozen vegetables
# rule 348: ['spaghetti', 'eggs'] => whole weat flour
# rule 349: ['spaghetti', 'french fries'] => frozen vegetables
# rule 350: ['mineral water', 'ground beef'] => tea
# rule 351: ['spaghetti', 'green tea'] => red wine
# rule 352: ['olive oil', 'mineral water'] => avocado
# rule 353: ['spaghetti', 'ground beef'] => oatmeal
# rule 354: ['spaghetti', 'green tea'] => cooking oil
# rule 355: ['french fries', 'eggs'] => burger sauce
# rule 356: ['spaghetti', 'chocolate'] => bacon
# rule 357: ['spaghetti', 'green tea'] => green beans
# rule 358: ['spaghetti', 'green tea'] => herb & pepper
# rule 359: ['pancakes', 'spaghetti'] => brownies
# rule 360: ['spaghetti', 'mineral water'] => cereals
# rule 361: ['french fries', 'eggs'] => gluten free bar
# rule 362: ['french fries', 'mineral water'] => babies food
# rule 363: ['spaghetti', 'chocolate'] => parmesan cheese
# rule 364: ['chocolate', 'eggs'] => eggplant
# rule 365: ['spaghetti', 'chocolate'] => protein bar
# rule 366: ['olive oil', 'mineral water'] => green grapes
# rule 367: ['french fries', 'mineral water'] => burgers
# rule 368: ['french fries', 'green tea'] => antioxydant juice
# rule 369: ['spaghetti', 'frozen vegetables'] => soup
# rule 370: ['spaghetti', 'french fries'] => tomato sauce
# rule 371: ['spaghetti', 'milk'] => toothpaste
# rule 372: ['mineral water', 'green tea'] => french wine
# rule 373: ['french fries', 'eggs'] => asparagus
# rule 374: ['spaghetti', 'french fries'] => milk
# rule 375: ['spaghetti', 'ground beef'] => french wine
# rule 376: ['spaghetti', 'green tea'] => rice
# rule 377: ['pancakes', 'spaghetti'] => tomato sauce
# rule 378: ['milk', 'eggs'] => butter
# rule 379: ['mineral water', 'chocolate'] => hand protein bar
# rule 380: ['pancakes', 'mineral water'] => ketchup
# rule 381: ['spaghetti', 'green tea'] => fromage blanc
# rule 382: ['mineral water', 'cake'] => bramble
# rule 383: ['mineral water', 'chocolate'] => corn
# rule 384: ['mineral water', 'milk'] => black tea
# rule 385: ['spaghetti', 'milk'] => burgers
# rule 386: ['milk', 'eggs'] => tea
# rule 387: ['spaghetti', 'frozen vegetables'] => nonfat milk
# rule 388: ['chocolate', 'milk'] => fromage blanc
# rule 389: ['chocolate', 'eggs'] => cake
# rule 390: ['mineral water', 'green tea'] => chicken
# rule 391: ['spaghetti', 'chocolate'] => pancakes
# rule 392: ['green tea', 'eggs'] => mashed potato
# rule 393: ['pancakes', 'mineral water'] => cooking oil
# rule 394: ['french fries', 'green tea'] => honey
# rule 395: ['french fries', 'mineral water'] => fresh tuna
# rule 396: ['pancakes', 'mineral water'] => red wine
# rule 397: ['french fries', 'green tea'] => tomato juice
# rule 398: ['french fries', 'mineral water'] => nonfat milk
# rule 399: ['chocolate', 'milk'] => olive oil
# rule 400: ['green tea', 'eggs'] => cereals
# rule 401: ['mineral water', 'green tea'] => brownies
# rule 402: ['spaghetti', 'frozen vegetables'] => olive oil
# rule 403: ['chocolate', 'milk'] => sparkling water
# rule 404: ['spaghetti', 'chocolate'] => tomatoes
# rule 405: ['french fries', 'chocolate'] => fromage blanc
# rule 406: ['spaghetti', 'french fries'] => chocolate
# rule 407: ['chocolate', 'milk'] => ground beef
# rule 408: ['spaghetti', 'ground beef'] => soup
# rule 409: ['pancakes', 'mineral water'] => asparagus
# rule 410: ['milk', 'eggs'] => cider
# rule 411: ['olive oil', 'mineral water'] => extra dark chocolate
# rule 412: ['spaghetti', 'french fries'] => magazines
# rule 413: ['spaghetti', 'french fries'] => green beans
# rule 414: ['spaghetti', 'frozen vegetables'] => burger sauce
# rule 415: ['pancakes', 'mineral water'] => almonds
# rule 416: ['spaghetti', 'milk'] => cauliflower
# rule 417: ['olive oil', 'mineral water'] => antioxydant juice
# rule 418: ['spaghetti', 'chocolate'] => tomato juice
# rule 419: ['spaghetti', 'french fries'] => fresh tuna
# rule 420: ['chocolate', 'milk'] => pancakes
# rule 421: ['burgers', 'eggs'] => chutney
# rule 422: ['mineral water', 'eggs'] => black tea
# rule 423: ['spaghetti', 'ground beef'] => extra dark chocolate
# rule 424: ['green tea', 'eggs'] => salt
# rule 425: ['olive oil', 'mineral water'] => white wine
# rule 426: ['olive oil', 'mineral water'] => chili
# rule 427: ['mineral water', 'milk'] => strong cheese
# rule 428: ['french fries', 'mineral water'] => tomato juice
# rule 429: ['spaghetti', 'french fries'] => burger sauce
# rule 430: ['mineral water', 'cake'] => mashed potato
# rule 431: ['spaghetti', 'eggs'] => burgers
# rule 432: ['french fries', 'chocolate'] => body spray
# rule 433: ['frozen vegetables', 'mineral water'] => chocolate
# rule 434: ['spaghetti', 'eggs'] => green beans
# rule 435: ['spaghetti', 'eggs'] => bramble
# rule 436: ['mineral water', 'green tea'] => clothes accessories
# rule 437: ['mineral water', 'milk'] => burgers
# rule 438: ['pancakes', 'mineral water'] => hand protein bar
# rule 439: ['chocolate', 'eggs'] => white wine
# rule 440: ['spaghetti', 'green tea'] => milk
# rule 441: ['milk', 'eggs'] => almonds
# rule 442: ['chocolate', 'milk'] => french wine
# rule 443: ['pancakes', 'mineral water'] => pepper
# rule 444: ['french fries', 'eggs'] => flax seed
# rule 445: ['chocolate', 'eggs'] => chutney
# rule 446: ['mineral water', 'ground beef'] => white wine
# rule 447: ['mineral water', 'eggs'] => ham
# rule 448: ['mineral water', 'cake'] => hot dogs
# rule 449: ['chocolate', 'milk'] => light cream
# rule 450: ['frozen vegetables', 'mineral water'] => protein bar
# rule 451: ['mineral water', 'cake'] => toothpaste
# rule 452: ['spaghetti', 'milk'] => salmon
# rule 453: ['pancakes', 'mineral water'] => cereals
# rule 454: ['mineral water', 'green tea'] => body spray
# rule 455: ['mineral water', 'chocolate'] => white wine
# rule 456: ['chocolate', 'eggs'] => cider
# rule 457: ['spaghetti', 'mineral water'] => tomatoes
# rule 458: ['spaghetti', 'green tea'] => corn
# rule 459: ['olive oil', 'mineral water'] => chicken
# rule 460: ['frozen vegetables', 'mineral water'] => black tea
# rule 461: ['burgers', 'eggs'] => fresh tuna
# rule 462: ['french fries', 'mineral water'] => blueberries
# rule 463: ['mineral water', 'milk'] => asparagus
# rule 464: ['mineral water', 'eggs'] => mashed potato
# rule 465: ['chocolate', 'eggs'] => gluten free bar
# rule 466: ['chocolate', 'milk'] => toothpaste
# rule 467: ['spaghetti', 'green tea'] => magazines
# rule 468: ['frozen vegetables', 'mineral water'] => hot dogs
# rule 469: ['mineral water', 'green tea'] => corn
# rule 470: ['spaghetti', 'frozen vegetables'] => grated cheese
# rule 471: ['mineral water', 'ground beef'] => dessert wine
# rule 472: ['spaghetti', 'milk'] => frozen smoothie
# rule 473: ['spaghetti', 'french fries'] => mayonnaise
# rule 474: ['french fries', 'mineral water'] => oatmeal
# rule 475: ['mineral water', 'milk'] => babies food
# rule 476: ['spaghetti', 'mineral water'] => chutney
# rule 477: ['spaghetti', 'mineral water'] => chili
# rule 478: ['mineral water', 'milk'] => blueberries
# rule 479: ['olive oil', 'mineral water'] => hot dogs
# rule 480: ['mineral water', 'cake'] => ham
# rule 481: ['mineral water', 'green tea'] => mashed potato
# rule 482: ['french fries', 'green tea'] => pasta
# rule 483: ['pancakes', 'mineral water'] => chili
# rule 484: ['chocolate', 'eggs'] => mashed potato
# rule 485: ['spaghetti', 'french fries'] => honey
# rule 486: ['mineral water', 'ground beef'] => chocolate
# rule 487: ['green tea', 'eggs'] => gums
# rule 488: ['spaghetti', 'ground beef'] => sparkling water
# rule 489: ['olive oil', 'mineral water'] => hand protein bar
# rule 490: ['french fries', 'chocolate'] => rice
# rule 491: ['mineral water', 'chocolate'] => shrimp
# rule 492: ['chocolate', 'eggs'] => tea
# rule 493: ['french fries', 'green tea'] => brownies
# rule 494: ['spaghetti', 'frozen vegetables'] => barbecue sauce
# rule 495: ['spaghetti', 'milk'] => corn
# rule 496: ['spaghetti', 'mineral water'] => green beans
# rule 497: ['french fries', 'eggs'] => bramble
# rule 498: ['mineral water', 'ground beef'] => burger sauce
# rule 499: ['frozen vegetables', 'mineral water'] => dessert wine
# rule 500: ['french fries', 'mineral water'] => fresh bread
# rule 501: ['frozen vegetables', 'mineral water'] => sparkling water
# rule 502: ['burgers', 'eggs'] => green tea
# rule 503: ['mineral water', 'chocolate'] => light cream
# rule 504: ['pancakes', 'mineral water'] => bacon
# rule 505: ['chocolate', 'milk'] => salmon
# rule 506: ['spaghetti', 'green tea'] => oil
# rule 507: ['frozen vegetables', 'mineral water'] => white wine
# rule 508: ['mineral water', 'cake'] => soup
# rule 509: ['frozen vegetables', 'mineral water'] => hand protein bar
# rule 510: ['mineral water', 'ground beef'] => cereals
# rule 511: ['pancakes', 'spaghetti'] => ham
# rule 512: ['spaghetti', 'ground beef'] => white wine
# rule 513: ['french fries', 'chocolate'] => strawberries
# rule 514: ['mineral water', 'cake'] => whole weat flour
# rule 515: ['french fries', 'mineral water'] => shampoo
# rule 516: ['mineral water', 'eggs'] => vegetables mix
# rule 517: ['mineral water', 'milk'] => cereals
# rule 518: ['spaghetti', 'green tea'] => chutney
# rule 519: ['spaghetti', 'frozen vegetables'] => whole weat flour
# rule 520: ['burgers', 'eggs'] => pasta
# rule 521: ['mineral water', 'ground beef'] => grated cheese
# rule 522: ['pancakes', 'spaghetti'] => fresh tuna
# rule 523: ['spaghetti', 'ground beef'] => light cream
# rule 524: ['pancakes', 'spaghetti'] => mint green tea
# rule 525: ['pancakes', 'spaghetti'] => chili
# rule 526: ['pancakes', 'mineral water'] => spaghetti
# rule 527: ['olive oil', 'mineral water'] => mint green tea
# rule 528: ['mineral water', 'milk'] => tomato juice
# rule 529: ['french fries', 'mineral water'] => soup
# rule 530: ['spaghetti', 'frozen vegetables'] => whole wheat rice
# rule 531: ['spaghetti', 'milk'] => cereals
# rule 532: ['spaghetti', 'french fries'] => mint green tea
# rule 533: ['french fries', 'mineral water'] => strawberries
# rule 534: ['milk', 'eggs'] => black tea
# rule 535: ['chocolate', 'eggs'] => spaghetti
# rule 536: ['spaghetti', 'chocolate'] => body spray
# rule 537: ['spaghetti', 'french fries'] => chutney
# rule 538: ['spaghetti', 'french fries'] => pickles
# rule 539: ['spaghetti', 'chocolate'] => frozen smoothie
# rule 540: ['spaghetti', 'ground beef'] => mineral water
# rule 541: ['french fries', 'chocolate'] => vegetables mix
# rule 542: ['mineral water', 'milk'] => tomato sauce
# rule 543: ['pancakes', 'spaghetti'] => avocado
# rule 544: ['milk', 'eggs'] => turkey
# rule 545: ['pancakes', 'spaghetti'] => burger sauce
# rule 546: ['pancakes', 'spaghetti'] => chutney
# rule 547: ['spaghetti', 'frozen vegetables'] => toothpaste
# rule 548: ['mineral water', 'eggs'] => toothpaste
# rule 549: ['spaghetti', 'french fries'] => light mayo
# rule 550: ['french fries', 'green tea'] => cider
# rule 551: ['spaghetti', 'chocolate'] => oil
# rule 552: ['green tea', 'eggs'] => bramble
# rule 553: ['chocolate', 'milk'] => low fat yogurt
# rule 554: ['pancakes', 'mineral water'] => cake
# rule 555: ['olive oil', 'mineral water'] => shrimp
# rule 556: ['french fries', 'mineral water'] => spinach
# rule 557: ['french fries', 'chocolate'] => whole wheat pasta
# rule 558: ['spaghetti', 'frozen vegetables'] => tea
# rule 559: ['spaghetti', 'mineral water'] => cream
# rule 560: ['french fries', 'mineral water'] => vegetables mix
# rule 561: ['frozen vegetables', 'mineral water'] => salmon
# rule 562: ['olive oil', 'mineral water'] => red wine
# rule 563: ['mineral water', 'cake'] => almonds
# rule 564: ['mineral water', 'milk'] => whole weat flour
# rule 565: ['french fries', 'mineral water'] => yams
# rule 566: ['french fries', 'mineral water'] => protein bar
# rule 567: ['mineral water', 'eggs'] => burger sauce
# rule 568: ['milk', 'eggs'] => oatmeal
# rule 569: ['french fries', 'eggs'] => muffins
# rule 570: ['spaghetti', 'eggs'] => whole wheat pasta
# rule 571: ['spaghetti', 'mineral water'] => nonfat milk
# rule 572: ['chocolate', 'milk'] => barbecue sauce
# rule 573: ['green tea', 'eggs'] => melons
# rule 574: ['spaghetti', 'mineral water'] => black tea
# rule 575: ['olive oil', 'mineral water'] => tomato juice
# rule 576: ['spaghetti', 'green tea'] => cider
# rule 577: ['frozen vegetables', 'mineral water'] => barbecue sauce
# rule 578: ['olive oil', 'mineral water'] => ground beef
# rule 579: ['spaghetti', 'ground beef'] => cereals
# rule 580: ['spaghetti', 'ground beef'] => whole wheat pasta
# rule 581: ['spaghetti', 'green tea'] => eggplant
# rule 582: ['mineral water', 'milk'] => red wine
# rule 583: ['french fries', 'green tea'] => chocolate bread
# rule 584: ['spaghetti', 'frozen vegetables'] => carrots
# rule 585: ['mineral water', 'eggs'] => dessert wine
# rule 586: ['spaghetti', 'green tea'] => tomato sauce
# rule 587: ['spaghetti', 'milk'] => chicken
# rule 588: ['olive oil', 'mineral water'] => chutney
# rule 589: ['spaghetti', 'mineral water'] => frozen smoothie
# rule 590: ['mineral water', 'green tea'] => shampoo
# rule 591: ['mineral water', 'chocolate'] => tomato sauce
# rule 592: ['mineral water', 'eggs'] => salad
# rule 593: ['spaghetti', 'milk'] => light cream
# rule 594: ['spaghetti', 'milk'] => almonds
# rule 595: ['spaghetti', 'eggs'] => zucchini
# rule 596: ['spaghetti', 'eggs'] => milk
# rule 597: ['green tea', 'eggs'] => pepper
# rule 598: ['french fries', 'green tea'] => shampoo
# rule 599: ['milk', 'eggs'] => fresh tuna
# rule 600: ['frozen vegetables', 'mineral water'] => shrimp
# rule 601: ['pancakes', 'mineral water'] => oatmeal
# rule 602: ['spaghetti', 'chocolate'] => avocado
# rule 603: ['spaghetti', 'ground beef'] => bug spray
# rule 604: ['mineral water', 'eggs'] => spaghetti
# rule 605: ['olive oil', 'mineral water'] => almonds
# rule 606: ['mineral water', 'chocolate'] => barbecue sauce
# rule 607: ['chocolate', 'milk'] => oatmeal
# rule 608: ['spaghetti', 'mineral water'] => salmon
# rule 609: ['frozen vegetables', 'mineral water'] => honey
# rule 610: ['french fries', 'eggs'] => cider
# rule 611: ['mineral water', 'ground beef'] => green grapes
# rule 612: ['spaghetti', 'green tea'] => zucchini
# rule 613: ['chocolate', 'milk'] => butter
# rule 614: ['spaghetti', 'chocolate'] => asparagus
# rule 615: ['spaghetti', 'ground beef'] => meatballs
# rule 616: ['burgers', 'eggs'] => gluten free bar
# rule 617: ['spaghetti', 'ground beef'] => chicken
# rule 618: ['chocolate', 'milk'] => clothes accessories
# rule 619: ['pancakes', 'mineral water'] => tomatoes
# rule 620: ['pancakes', 'mineral water'] => sandwich
# rule 621: ['mineral water', 'cake'] => tomatoes
# rule 622: ['spaghetti', 'ground beef'] => shrimp
# rule 623: ['pancakes', 'mineral water'] => whole wheat rice
# rule 624: ['spaghetti', 'green tea'] => vegetables mix
# rule 625: ['spaghetti', 'chocolate'] => pasta
# rule 626: ['pancakes', 'spaghetti'] => whole wheat pasta
# rule 627: ['spaghetti', 'mineral water'] => grated cheese
# rule 628: ['spaghetti', 'eggs'] => mineral water
# rule 629: ['mineral water', 'cake'] => spinach
# rule 630: ['french fries', 'chocolate'] => mint green tea
# rule 631: ['spaghetti', 'mineral water'] => parmesan cheese
# rule 632: ['spaghetti', 'eggs'] => cake
# rule 633: ['pancakes', 'mineral water'] => oil
# rule 634: ['mineral water', 'chocolate'] => spaghetti
# rule 635: ['chocolate', 'eggs'] => sandwich
# rule 636: ['frozen vegetables', 'mineral water'] => chicken
# rule 637: ['chocolate', 'milk'] => babies food
# rule 638: ['frozen vegetables', 'mineral water'] => chutney
# rule 639: ['spaghetti', 'frozen vegetables'] => fresh tuna
# rule 640: ['spaghetti', 'frozen vegetables'] => light cream
# rule 641: ['mineral water', 'green tea'] => tomato sauce
# rule 642: ['spaghetti', 'mineral water'] => napkins
# rule 643: ['french fries', 'mineral water'] => shallot
# rule 644: ['mineral water', 'eggs'] => green grapes
# rule 645: ['spaghetti', 'ground beef'] => burger sauce
# rule 646: ['spaghetti', 'frozen vegetables'] => tomatoes
# rule 647: ['spaghetti', 'milk'] => blueberries
# rule 648: ['mineral water', 'eggs'] => corn
# rule 649: ['chocolate', 'milk'] => tea
# rule 650: ['olive oil', 'mineral water'] => honey
# rule 651: ['spaghetti', 'green tea'] => whole weat flour
# rule 652: ['spaghetti', 'green tea'] => protein bar
# rule 653: ['french fries', 'eggs'] => fresh tuna
# rule 654: ['spaghetti', 'eggs'] => cream
# rule 655: ['mineral water', 'chocolate'] => burger sauce
# rule 656: ['spaghetti', 'mineral water'] => mayonnaise
# rule 657: ['french fries', 'green tea'] => ketchup
# rule 658: ['mineral water', 'chocolate'] => oatmeal
# rule 659: ['french fries', 'eggs'] => melons
# rule 660: ['olive oil', 'mineral water'] => milk
# rule 661: ['french fries', 'mineral water'] => muffins
# rule 662: ['spaghetti', 'eggs'] => melons
# rule 663: ['spaghetti', 'mineral water'] => mint
# rule 664: ['french fries', 'chocolate'] => salt
# rule 665: ['burgers', 'eggs'] => almonds
# rule 666: ['spaghetti', 'frozen vegetables'] => chocolate
# rule 667: ['french fries', 'mineral water'] => cider
# rule 668: ['french fries', 'mineral water'] => burger sauce
# rule 669: ['mineral water', 'ground beef'] => turkey
# rule 670: ['spaghetti', 'chocolate'] => pet food
# rule 671: ['chocolate', 'eggs'] => ham
# rule 672: ['mineral water', 'milk'] => frozen smoothie
# rule 673: ['mineral water', 'milk'] => energy bar
# rule 674: ['pancakes', 'spaghetti'] => gluten free bar
# rule 675: ['frozen vegetables', 'mineral water'] => milk
# rule 676: ['green tea', 'eggs'] => blueberries
# rule 677: ['mineral water', 'milk'] => cooking oil
# rule 678: ['french fries', 'green tea'] => shallot
# rule 679: ['spaghetti', 'eggs'] => light cream
# rule 680: ['olive oil', 'mineral water'] => cooking oil
# rule 681: ['olive oil', 'mineral water'] => pickles
# rule 682: ['spaghetti', 'green tea'] => ground beef
# rule 683: ['spaghetti', 'milk'] => pepper
# rule 684: ['pancakes', 'spaghetti'] => oil
# rule 685: ['mineral water', 'eggs'] => chocolate
# rule 686: ['mineral water', 'green tea'] => ground beef
# rule 687: ['mineral water', 'ground beef'] => extra dark chocolate
# rule 688: ['mineral water', 'green tea'] => whole weat flour
# rule 689: ['pancakes', 'spaghetti'] => fromage blanc
# rule 690: ['chocolate', 'eggs'] => soup
# rule 691: ['pancakes', 'mineral water'] => mayonnaise
# rule 692: ['mineral water', 'green tea'] => black tea
# rule 693: ['mineral water', 'milk'] => french wine
# rule 694: ['mineral water', 'green tea'] => vegetables mix
# rule 695: ['frozen vegetables', 'mineral water'] => gluten free bar
# rule 696: ['spaghetti', 'frozen vegetables'] => bacon
# rule 697: ['mineral water', 'milk'] => shrimp
# rule 698: ['french fries', 'mineral water'] => cake
# rule 699: ['spaghetti', 'chocolate'] => frozen vegetables
# rule 700: ['frozen vegetables', 'mineral water'] => green beans
# rule 701: ['spaghetti', 'green tea'] => energy drink
# rule 702: ['milk', 'eggs'] => cake
# rule 703: ['french fries', 'eggs'] => burgers
# rule 704: ['milk', 'eggs'] => spinach
# rule 705: ['mineral water', 'milk'] => olive oil
# rule 706: ['frozen vegetables', 'mineral water'] => fresh tuna
# rule 707: ['spaghetti', 'mineral water'] => white wine
# rule 708: ['mineral water', 'cake'] => olive oil
# rule 709: ['spaghetti', 'french fries'] => tomato juice
# rule 710: ['mineral water', 'ground beef'] => tomato sauce
# rule 711: ['spaghetti', 'milk'] => cottage cheese
# rule 712: ['chocolate', 'milk'] => white wine
# rule 713: ['spaghetti', 'ground beef'] => parmesan cheese
# rule 714: ['mineral water', 'eggs'] => tomato sauce
# rule 715: ['mineral water', 'green tea'] => spaghetti
# rule 716: ['mineral water', 'green tea'] => mayonnaise
# rule 717: ['spaghetti', 'ground beef'] => ketchup
# rule 718: ['burgers', 'eggs'] => light mayo
# rule 719: ['mineral water', 'chocolate'] => salmon
# rule 720: ['spaghetti', 'frozen vegetables'] => tomato juice
# rule 721: ['spaghetti', 'milk'] => chocolate
# rule 722: ['spaghetti', 'frozen vegetables'] => oatmeal
# rule 723: ['burgers', 'eggs'] => salt
# rule 724: ['frozen vegetables', 'mineral water'] => green grapes
# rule 725: ['spaghetti', 'french fries'] => body spray
# rule 726: ['chocolate', 'milk'] => pepper
# rule 727: ['pancakes', 'mineral water'] => rice
# rule 728: ['spaghetti', 'chocolate'] => mineral water
# rule 729: ['mineral water', 'chocolate'] => pepper
# rule 730: ['spaghetti', 'ground beef'] => cream
# rule 731: ['spaghetti', 'frozen vegetables'] => frozen smoothie
# rule 732: ['french fries', 'green tea'] => hand protein bar
# rule 733: ['green tea', 'eggs'] => green grapes
# rule 734: ['spaghetti', 'french fries'] => bug spray
# rule 735: ['spaghetti', 'milk'] => shampoo
# rule 736: ['french fries', 'green tea'] => yams
# rule 737: ['mineral water', 'chocolate'] => clothes accessories
# rule 738: ['spaghetti', 'ground beef'] => red wine
# rule 739: ['french fries', 'green tea'] => pet food
# rule 740: ['pancakes', 'spaghetti'] => light cream
# rule 741: ['spaghetti', 'green tea'] => green grapes
# rule 742: ['spaghetti', 'eggs'] => strong cheese
# rule 743: ['spaghetti', 'eggs'] => nonfat milk
# rule 744: ['frozen vegetables', 'mineral water'] => toothpaste
# rule 745: ['green tea', 'eggs'] => almonds
# rule 746: ['chocolate', 'milk'] => cereals
# rule 747: ['french fries', 'mineral water'] => green grapes
# rule 748: ['mineral water', 'eggs'] => brownies
# rule 749: ['spaghetti', 'green tea'] => pancakes
# rule 750: ['pancakes', 'spaghetti'] => green beans
# rule 751: ['french fries', 'green tea'] => clothes accessories
# rule 752: ['spaghetti', 'eggs'] => chicken
# rule 753: ['french fries', 'green tea'] => whole weat flour
# rule 754: ['spaghetti', 'french fries'] => mineral water
# rule 755: ['french fries', 'green tea'] => strawberries
# rule 756: ['spaghetti', 'chocolate'] => toothpaste
# rule 757: ['mineral water', 'ground beef'] => mayonnaise
# rule 758: ['spaghetti', 'mineral water'] => cauliflower
# rule 759: ['mineral water', 'eggs'] => oatmeal
# rule 760: ['pancakes', 'spaghetti'] => pepper
# rule 761: ['spaghetti', 'eggs'] => almonds
# rule 762: ['french fries', 'chocolate'] => shampoo
# rule 763: ['pancakes', 'spaghetti'] => toothpaste
# rule 764: ['spaghetti', 'mineral water'] => chicken
# rule 765: ['spaghetti', 'chocolate'] => french wine
# rule 766: ['spaghetti', 'ground beef'] => nonfat milk
# rule 767: ['spaghetti', 'green tea'] => mashed potato
# rule 768: ['chocolate', 'eggs'] => olive oil
# rule 769: ['mineral water', 'milk'] => rice
# rule 770: ['chocolate', 'eggs'] => butter
# rule 771: ['burgers', 'eggs'] => meatballs
# rule 772: ['mineral water', 'ground beef'] => nonfat milk
# rule 773: ['spaghetti', 'french fries'] => green grapes
# rule 774: ['chocolate', 'eggs'] => vegetables mix
# rule 775: ['milk', 'eggs'] => parmesan cheese
# rule 776: ['burgers', 'eggs'] => fromage blanc
# rule 777: ['milk', 'eggs'] => chocolate
# rule 778: ['spaghetti', 'frozen vegetables'] => bug spray
# rule 779: ['frozen vegetables', 'mineral water'] => cooking oil
# rule 780: ['mineral water', 'green tea'] => almonds
# rule 781: ['spaghetti', 'mineral water'] => rice
# rule 782: ['pancakes', 'mineral water'] => clothes accessories
# rule 783: ['pancakes', 'spaghetti'] => french wine
# rule 784: ['mineral water', 'milk'] => carrots
# rule 785: ['french fries', 'chocolate'] => flax seed
# rule 786: ['spaghetti', 'ground beef'] => strong cheese
# rule 787: ['french fries', 'eggs'] => ketchup
# rule 788: ['spaghetti', 'french fries'] => ham
# rule 789: ['spaghetti', 'green tea'] => bacon
# rule 790: ['spaghetti', 'french fries'] => olive oil
# rule 791: ['spaghetti', 'french fries'] => cider
# rule 792: ['mineral water', 'cake'] => whole wheat rice
# rule 793: ['spaghetti', 'mineral water'] => hot dogs
# rule 794: ['mineral water', 'chocolate'] => strong cheese
# rule 795: ['mineral water', 'green tea'] => honey
# rule 796: ['mineral water', 'milk'] => ketchup
# rule 797: ['frozen vegetables', 'mineral water'] => cake
# rule 798: ['burgers', 'eggs'] => pancakes
# rule 799: ['burgers', 'eggs'] => flax seed
# rule 800: ['mineral water', 'green tea'] => turkey
# rule 801: ['milk', 'eggs'] => frozen vegetables
# rule 802: ['spaghetti', 'green tea'] => salmon
# rule 803: ['chocolate', 'eggs'] => mayonnaise
# rule 804: ['mineral water', 'cake'] => pancakes
# rule 805: ['mineral water', 'ground beef'] => black tea
# rule 806: ['french fries', 'mineral water'] => strong cheese
# rule 807: ['spaghetti', 'green tea'] => mayonnaise
# rule 808: ['spaghetti', 'french fries'] => cereals
# rule 809: ['mineral water', 'ground beef'] => chutney
# rule 810: ['spaghetti', 'green tea'] => extra dark chocolate
# rule 811: ['chocolate', 'milk'] => frozen vegetables
# rule 812: ['mineral water', 'milk'] => corn
# rule 813: ['spaghetti', 'mineral water'] => frozen vegetables
# rule 814: ['french fries', 'green tea'] => blueberries
# rule 815: ['spaghetti', 'mineral water'] => ham
# rule 816: ['pancakes', 'mineral water'] => extra dark chocolate
# rule 817: ['french fries', 'mineral water'] => mint green tea
# rule 818: ['frozen vegetables', 'mineral water'] => whole wheat pasta
# rule 819: ['pancakes', 'spaghetti'] => bacon
# rule 820: ['mineral water', 'ground beef'] => french wine
# rule 821: ['french fries', 'chocolate'] => sandwich
# rule 822: ['mineral water', 'milk'] => eggs
# rule 823: ['french fries', 'green tea'] => cookies
# rule 824: ['spaghetti', 'ground beef'] => sandwich
# rule 825: ['french fries', 'chocolate'] => champagne
# rule 826: ['french fries', 'mineral water'] => frozen smoothie
# rule 827: ['spaghetti', 'milk'] => black tea
# rule 828: ['spaghetti', 'eggs'] => ham
# rule 829: ['mineral water', 'ground beef'] => meatballs
# rule 830: ['mineral water', 'cake'] => turkey
# rule 831: ['french fries', 'mineral water'] => ham
# rule 832: ['pancakes', 'spaghetti'] => bug spray
# rule 833: ['french fries', 'chocolate'] => mushroom cream sauce
# rule 834: ['mineral water', 'milk'] => cauliflower
# rule 835: ['frozen vegetables', 'mineral water'] => clothes accessories
# rule 836: ['pancakes', 'mineral water'] => chicken
# rule 837: ['mineral water', 'ground beef'] => frozen vegetables
# rule 838: ['spaghetti', 'milk'] => tomato sauce
# rule 839: ['pancakes', 'spaghetti'] => cake
# rule 840: ['spaghetti', 'ground beef'] => napkins
# rule 841: ['spaghetti', 'frozen vegetables'] => clothes accessories
# rule 842: ['mineral water', 'green tea'] => zucchini
# rule 843: ['olive oil', 'mineral water'] => candy bars
# rule 844: ['mineral water', 'ground beef'] => toothpaste
# rule 845: ['spaghetti', 'frozen vegetables'] => ground beef
# rule 846: ['mineral water', 'eggs'] => nonfat milk
# rule 847: ['pancakes', 'mineral water'] => avocado
# rule 848: ['mineral water', 'eggs'] => pet food
# rule 849: ['mineral water', 'chocolate'] => avocado
# rule 850: ['mineral water', 'green tea'] => green grapes
# rule 851: ['spaghetti', 'milk'] => zucchini
# rule 852: ['spaghetti', 'ground beef'] => cooking oil
# rule 853: ['pancakes', 'mineral water'] => blueberries
# rule 854: ['mineral water', 'cake'] => cauliflower
# rule 855: ['olive oil', 'mineral water'] => whole wheat pasta
# rule 856: ['french fries', 'chocolate'] => brownies
# rule 857: ['pancakes', 'spaghetti'] => napkins
# rule 858: ['chocolate', 'milk'] => melons
# rule 859: ['spaghetti', 'mineral water'] => green grapes
# rule 860: ['mineral water', 'eggs'] => cooking oil
# rule 861: ['french fries', 'chocolate'] => tomato juice
# rule 862: ['chocolate', 'eggs'] => corn
# rule 863: ['spaghetti', 'french fries'] => spinach
# rule 864: ['frozen vegetables', 'mineral water'] => bacon
# rule 865: ['spaghetti', 'frozen vegetables'] => pepper
# rule 866: ['spaghetti', 'green tea'] => black tea
# rule 867: ['french fries', 'mineral water'] => milk
# rule 868: ['spaghetti', 'eggs'] => chocolate
# rule 869: ['green tea', 'eggs'] => cider
# rule 870: ['pancakes', 'mineral water'] => chocolate bread
# rule 871: ['mineral water', 'milk'] => fresh bread
# rule 872: ['pancakes', 'spaghetti'] => white wine
# rule 873: ['spaghetti', 'eggs'] => herb & pepper
# rule 874: ['spaghetti', 'milk'] => dessert wine
# rule 875: ['burgers', 'eggs'] => corn
# rule 876: ['spaghetti', 'mineral water'] => bug spray
# rule 877: ['spaghetti', 'green tea'] => turkey
# rule 878: ['milk', 'eggs'] => toothpaste
# rule 879: ['chocolate', 'eggs'] => herb & pepper
# rule 880: ['mineral water', 'eggs'] => red wine
# rule 881: ['mineral water', 'milk'] => bramble
# rule 882: ['mineral water', 'milk'] => frozen vegetables
# rule 883: ['chocolate', 'milk'] => shrimp
# rule 884: ['spaghetti', 'frozen vegetables'] => milk
# rule 885: ['mineral water', 'ground beef'] => chocolate bread
# rule 886: ['mineral water', 'milk'] => whole wheat rice
# rule 887: ['spaghetti', 'eggs'] => oatmeal
# rule 888: ['mineral water', 'cake'] => extra dark chocolate
# rule 889: ['olive oil', 'mineral water'] => bug spray
# rule 890: ['mineral water', 'green tea'] => soup
# rule 891: ['pancakes', 'mineral water'] => shampoo
# rule 892: ['frozen vegetables', 'mineral water'] => nonfat milk
# rule 893: ['french fries', 'green tea'] => babies food
# rule 894: ['pancakes', 'spaghetti'] => cream
# rule 895: ['chocolate', 'eggs'] => shrimp
# rule 896: ['green tea', 'eggs'] => pet food
# rule 897: ['olive oil', 'mineral water'] => yogurt cake
# rule 898: ['mineral water', 'milk'] => sparkling water
# rule 899: ['french fries', 'green tea'] => spinach
# rule 900: ['pancakes', 'mineral water'] => fresh tuna
# rule 901: ['french fries', 'mineral water'] => melons
# rule 902: ['milk', 'eggs'] => pancakes
# rule 903: ['french fries', 'mineral water'] => cottage cheese
# rule 904: ['milk', 'eggs'] => red wine
# rule 905: ['mineral water', 'green tea'] => bramble
# rule 906: ['spaghetti', 'ground beef'] => toothpaste
# rule 907: ['pancakes', 'spaghetti'] => herb & pepper
# rule 908: ['french fries', 'chocolate'] => butter
# rule 909: ['spaghetti', 'french fries'] => french wine
# rule 910: ['spaghetti', 'eggs'] => cider
# rule 911: ['mineral water', 'ground beef'] => rice
# rule 912: ['spaghetti', 'mineral water'] => oil
# rule 913: ['olive oil', 'mineral water'] => brownies
# rule 914: ['spaghetti', 'eggs'] => chutney
# rule 915: ['spaghetti', 'mineral water'] => meatballs
# rule 916: ['spaghetti', 'green tea'] => french wine
# rule 917: ['green tea', 'eggs'] => brownies
# rule 918: ['pancakes', 'spaghetti'] => eggplant
# rule 919: ['pancakes', 'spaghetti'] => energy drink
# rule 920: ['chocolate', 'milk'] => oil
# rule 921: ['french fries', 'mineral water'] => red wine
# rule 922: ['green tea', 'eggs'] => fromage blanc
# rule 923: ['mineral water', 'ground beef'] => bug spray
# rule 924: ['frozen vegetables', 'mineral water'] => strawberries
# rule 925: ['pancakes', 'mineral water'] => magazines
# rule 926: ['chocolate', 'milk'] => cooking oil
# rule 927: ['spaghetti', 'french fries'] => turkey
# rule 928: ['spaghetti', 'chocolate'] => flax seed
# rule 929: ['chocolate', 'milk'] => spaghetti
# rule 930: ['french fries', 'green tea'] => corn
# rule 931: ['spaghetti', 'ground beef'] => tomatoes
# ...
# rule 1287: ['french fries', 'green tea'] => flax seed
# rule 1288: ['chocolate', 'milk'] => herb & pepper
# rule 1289: ['spaghetti', 'chocolate'] => soup
# rule 1290: ['spaghetti', 'french fries'] => melons
# rule 1291: ['mineral water', 'ground beef'] => gums
# rule 1292: ['green tea', 'eggs'] => chutney
# rule 1293: ['milk', 'eggs'] => whole wheat pasta
# rule 1294: ['frozen vegetables', 'mineral water'] => vegetables mix
# rule 1295: ['mineral water', 'eggs'] => olive oil
# rule 1296: ['spaghetti', 'milk'] => hot dogs
# rule 1297: ['mineral water', 'milk'] => ground beef
# rule 1298: ['spaghetti', 'frozen vegetables'] => strong cheese
# rule 1299: ['spaghetti', 'chocolate'] => tea
# rule 1300: ['pancakes', 'spaghetti'] => burgers
# rule 1301: ['french fries', 'green tea'] => bramble
# rule 1302: ['spaghetti', 'mineral water'] => mashed potato
# rule 1303: ['spaghetti', 'mineral water'] => oatmeal
# rule 1304: ['olive oil', 'mineral water'] => grated cheese
# rule 1305: ['mineral water', 'milk'] => spinach
# rule 1306: ['spaghetti', 'ground beef'] => milk
# rule 1307: ['mineral water', 'green tea'] => olive oil
# rule 1308: ['mineral water', 'cake'] => milk
# rule 1309: ['spaghetti', 'ground beef'] => tomato sauce
# rule 1310: ['french fries', 'chocolate'] => low fat yogurt
# rule 1311: ['chocolate', 'milk'] => energy bar
# rule 1312: ['spaghetti', 'milk'] => gums
# rule 1313: ['spaghetti', 'chocolate'] => white wine
# rule 1314: ['spaghetti', 'ground beef'] => barbecue sauce
# rule 1315: ['mineral water', 'ground beef'] => salmon
# rule 1316: ['olive oil', 'mineral water'] => asparagus
# rule 1317: ['mineral water', 'cake'] => parmesan cheese
# rule 1318: ['spaghetti', 'chocolate'] => burger sauce
# rule 1319: ['mineral water', 'cake'] => cottage cheese
# rule 1320: ['spaghetti', 'mineral water'] => whole wheat rice
# rule 1321: ['spaghetti', 'ground beef'] => salmon
# rule 1322: ['mineral water', 'ground beef'] => protein bar
# rule 1323: ['french fries', 'green tea'] => mashed potato
# rule 1324: ['mineral water', 'milk'] => soup
# rule 1325: ['mineral water', 'eggs'] => chutney
# rule 1326: ['spaghetti', 'chocolate'] => nonfat milk
# rule 1327: ['mineral water', 'milk'] => oil
# rule 1328: ['french fries', 'green tea'] => almonds
# rule 1329: ['french fries', 'mineral water'] => antioxydant juice
# rule 1330: ['mineral water', 'milk'] => cake
# rule 1331: ['mineral water', 'chocolate'] => napkins
# rule 1332: ['olive oil', 'mineral water'] => french wine
# rule 1333: ['french fries', 'green tea'] => chili
# rule 1334: ['pancakes', 'spaghetti'] => hot dogs
# rule 1335: ['spaghetti', 'green tea'] => tomatoes
# rule 1336: ['spaghetti', 'mineral water'] => spinach
# rule 1337: ['mineral water', 'ground beef'] => bramble
# rule 1338: ['pancakes', 'mineral water'] => body spray
# rule 1339: ['mineral water', 'eggs'] => cider
# rule 1340: ['chocolate', 'eggs'] => blueberries
# rule 1341: ['spaghetti', 'ground beef'] => protein bar
# rule 1342: ['spaghetti', 'eggs'] => shrimp
# rule 1343: ['spaghetti', 'ground beef'] => burgers
# rule 1344: ['green tea', 'eggs'] => cake
# rule 1345: ['spaghetti', 'ground beef'] => almonds
# rule 1346: ['mineral water', 'eggs'] => soup
# rule 1347: ['milk', 'eggs'] => low fat yogurt
# rule 1348: ['spaghetti', 'eggs'] => fromage blanc
# rule 1349: ['spaghetti', 'green tea'] => chocolate
# rule 1350: ['pancakes', 'mineral water'] => fromage blanc
# rule 1351: ['mineral water', 'cake'] => red wine
# rule 1352: ['spaghetti', 'eggs'] => turkey
# rule 1353: ['mineral water', 'milk'] => light cream
# rule 1354: ['spaghetti', 'green tea'] => cottage cheese
# rule 1355: ['milk', 'eggs'] => ham
# rule 1356: ['mineral water', 'ground beef'] => chili
# rule 1357: ['mineral water', 'green tea'] => pancakes
# rule 1358: ['spaghetti', 'frozen vegetables'] => mineral water
# rule 1359: ['chocolate', 'eggs'] => light cream
# rule 1360: ['mineral water', 'eggs'] => spinach
# rule 1361: ['spaghetti', 'milk'] => whole wheat rice
# rule 1362: ['spaghetti', 'french fries'] => bramble
# rule 1363: ['pancakes', 'mineral water'] => shrimp
# rule 1364: ['spaghetti', 'chocolate'] => fresh bread
# rule 1365: ['french fries', 'green tea'] => oatmeal
# rule 1366: ['mineral water', 'cake'] => frozen vegetables
# rule 1367: ['french fries', 'green tea'] => green grapes
# rule 1368: ['olive oil', 'mineral water'] => melons
# rule 1369: ['spaghetti', 'green tea'] => grated cheese
# rule 1370: ['french fries', 'eggs'] => bacon
# rule 1371: ['mineral water', 'chocolate'] => protein bar
# rule 1372: ['chocolate', 'eggs'] => zucchini
# rule 1373: ['milk', 'eggs'] => light cream
# rule 1374: ['olive oil', 'mineral water'] => herb & pepper
# rule 1375: ['spaghetti', 'frozen vegetables'] => zucchini
# rule 1376: ['french fries', 'eggs'] => turkey
# rule 1377: ['spaghetti', 'chocolate'] => ketchup
# rule 1378: ['spaghetti', 'french fries'] => carrots
# rule 1379: ['french fries', 'mineral water'] => corn
# rule 1380: ['spaghetti', 'frozen vegetables'] => green beans
# rule 1381: ['spaghetti', 'mineral water'] => melons
# rule 1382: ['spaghetti', 'milk'] => bug spray
# rule 1383: ['spaghetti', 'french fries'] => frozen smoothie
# rule 1384: ['olive oil', 'mineral water'] => strong cheese
# rule 1385: ['spaghetti', 'frozen vegetables'] => ketchup
# rule 1386: ['spaghetti', 'green tea'] => pepper
# rule 1387: ['milk', 'eggs'] => chicken
# rule 1388: ['mineral water', 'ground beef'] => ham
# rule 1389: ['burgers', 'eggs'] => ham
# rule 1390: ['spaghetti', 'chocolate'] => tomato sauce
# rule 1391: ['french fries', 'mineral water'] => avocado
# rule 1392: ['french fries', 'chocolate'] => magazines
# rule 1393: ['french fries', 'green tea'] => body spray
# rule 1394: ['olive oil', 'mineral water'] => zucchini
# rule 1395: ['spaghetti', 'chocolate'] => butter
# rule 1396: ['french fries', 'eggs'] => mint green tea
# rule 1397: ['mineral water', 'eggs'] => extra dark chocolate
# rule 1398: ['mineral water', 'cake'] => sparkling water
# rule 1399: ['mineral water', 'green tea'] => fromage blanc
# rule 1400: ['chocolate', 'eggs'] => mineral water
# rule 1401: ['chocolate', 'milk'] => mineral water
# rule 1402: ['mineral water', 'eggs'] => french wine
# rule 1403: ['frozen vegetables', 'mineral water'] => herb & pepper
# rule 1404: ['spaghetti', 'eggs'] => pepper
# rule 1405: ['olive oil', 'mineral water'] => soup
# rule 1406: ['french fries', 'eggs'] => milk
# rule 1407: ['mineral water', 'eggs'] => ground beef
# rule 1408: ['spaghetti', 'eggs'] => asparagus
# rule 1409: ['mineral water', 'eggs'] => gluten free bar
# rule 1410: ['spaghetti', 'green tea'] => mushroom cream sauce
# rule 1411: ['french fries', 'green tea'] => pancakes
# rule 1412: ['mineral water', 'green tea'] => red wine
# rule 1413: ['chocolate', 'eggs'] => asparagus
# rule 1414: ['milk', 'eggs'] => shrimp
# rule 1415: ['chocolate', 'eggs'] => cooking oil
# rule 1416: ['spaghetti', 'mineral water'] => cooking oil
# rule 1417: ['spaghetti', 'milk'] => ham
# rule 1418: ['spaghetti', 'french fries'] => light cream
# rule 1419: ['spaghetti', 'frozen vegetables'] => pancakes
# rule 1420: ['spaghetti', 'french fries'] => bacon
# rule 1421: ['mineral water', 'green tea'] => chili
# rule 1422: ['spaghetti', 'milk'] => soup
# rule 1423: ['olive oil', 'mineral water'] => cauliflower
# rule 1424: ['spaghetti', 'milk'] => frozen vegetables
# rule 1425: ['spaghetti', 'eggs'] => body spray
# rule 1426: ['pancakes', 'spaghetti'] => ketchup
# rule 1427: ['mineral water', 'ground beef'] => whole wheat rice
# rule 1428: ['green tea', 'eggs'] => french fries
# rule 1429: ['green tea', 'eggs'] => fresh tuna
# rule 1430: ['spaghetti', 'frozen vegetables'] => ham
# rule 1431: ['chocolate', 'milk'] => eggs
# rule 1432: ['pancakes', 'spaghetti'] => turkey
# rule 1433: ['spaghetti', 'green tea'] => frozen smoothie
# rule 1434: ['spaghetti', 'green tea'] => carrots
# rule 1435: ['green tea', 'eggs'] => bacon
# rule 1436: ['french fries', 'chocolate'] => almonds
# rule 1437: ['green tea', 'eggs'] => burgers
# rule 1438: ['mineral water', 'eggs'] => frozen vegetables
# rule 1439: ['milk', 'eggs'] => cooking oil
# rule 1440: ['chocolate', 'milk'] => fresh bread
# rule 1441: ['frozen vegetables', 'mineral water'] => tomatoes
# rule 1442: ['chocolate', 'eggs'] => nonfat milk
# rule 1443: ['mineral water', 'ground beef'] => low fat yogurt
# rule 1444: ['french fries', 'chocolate'] => frozen vegetables
# rule 1445: ['spaghetti', 'french fries'] => hot dogs
# rule 1446: ['spaghetti', 'frozen vegetables'] => gums
# rule 1447: ['spaghetti', 'ground beef'] => green grapes
# rule 1448: ['mineral water', 'green tea'] => oatmeal
# rule 1449: ['frozen vegetables', 'mineral water'] => extra dark chocolate
# rule 1450: ['french fries', 'mineral water'] => eggplant
# rule 1451: ['mineral water', 'ground beef'] => tomatoes
# rule 1452: ['spaghetti', 'chocolate'] => hot dogs
# rule 1453: ['chocolate', 'eggs'] => french wine
# rule 1454: ['spaghetti', 'milk'] => red wine
# rule 1455: ['mineral water', 'green tea'] => fresh bread
# rule 1456: ['spaghetti', 'milk'] => protein bar
# rule 1457: ['chocolate', 'eggs'] => red wine
# rule 1458: ['frozen vegetables', 'mineral water'] => chocolate bread
# rule 1459: ['spaghetti', 'french fries'] => flax seed
# rule 1460: ['mineral water', 'chocolate'] => milk
# rule 1461: ['french fries', 'mineral water'] => whole wheat rice
# rule 1462: ['spaghetti', 'chocolate'] => red wine
# rule 1463: ['chocolate', 'milk'] => vegetables mix
# rule 1464: ['mineral water', 'green tea'] => extra dark chocolate
# rule 1465: ['spaghetti', 'ground beef'] => mashed potato
# rule 1466: ['spaghetti', 'mineral water'] => mint green tea
# rule 1467: ['spaghetti', 'green tea'] => babies food
# rule 1468: ['mineral water', 'milk'] => burger sauce
# rule 1469: ['spaghetti', 'french fries'] => herb & pepper
# rule 1470: ['spaghetti', 'frozen vegetables'] => meatballs
# rule 1471: ['spaghetti', 'ground beef'] => mayonnaise
# rule 1472: ['pancakes', 'spaghetti'] => blueberries
# rule 1473: ['frozen vegetables', 'mineral water'] => olive oil
# rule 1474: ['spaghetti', 'mineral water'] => fresh tuna
# rule 1475: ['mineral water', 'chocolate'] => ham
# rule 1476: ['mineral water', 'green tea'] => bacon
# rule 1477: ['spaghetti', 'green tea'] => flax seed
# rule 1478: ['spaghetti', 'french fries'] => salt
# rule 1479: ['mineral water', 'ground beef'] => clothes accessories
# rule 1480: ['spaghetti', 'eggs'] => soup
# rule 1481: ['spaghetti', 'chocolate'] => mayonnaise
# rule 1482: ['spaghetti', 'eggs'] => red wine
# rule 1483: ['spaghetti', 'french fries'] => tomatoes
# rule 1484: ['chocolate', 'eggs'] => tomato sauce
# rule 1485: ['spaghetti', 'milk'] => strong cheese
# rule 1486: ['french fries', 'mineral water'] => frozen vegetables
# rule 1487: ['burgers', 'eggs'] => black tea
# rule 1488: ['spaghetti', 'chocolate'] => bug spray
# rule 1489: ['spaghetti', 'ground beef'] => dessert wine
# rule 1490: ['spaghetti', 'green tea'] => oatmeal
# rule 1491: ['spaghetti', 'milk'] => ketchup
# rule 1492: ['spaghetti', 'milk'] => cream
# rule 1493: ['spaghetti', 'milk'] => spinach
# rule 1494: ['mineral water', 'chocolate'] => mayonnaise
# rule 1495: ['french fries', 'chocolate'] => babies food
# rule 1496: ['mineral water', 'cake'] => chicken
# rule 1497: ['spaghetti', 'eggs'] => brownies
# rule 1498: ['pancakes', 'mineral water'] => white wine
# rule 1499: ['spaghetti', 'french fries'] => shampoo
# rule 1500: ['olive oil', 'mineral water'] => cereals
# rule 1501: ['french fries', 'green tea'] => whole wheat rice
# rule 1502: ['chocolate', 'milk'] => bacon
# rule 1503: ['french fries', 'chocolate'] => avocado
# rule 1504: ['mineral water', 'cake'] => burger sauce
# rule 1505: ['pancakes', 'mineral water'] => french wine
# rule 1506: ['mineral water', 'eggs'] => soda
# rule 1507: ['pancakes', 'spaghetti'] => olive oil
# rule 1508: ['milk', 'eggs'] => bramble
# rule 1509: ['chocolate', 'milk'] => avocado
# rule 1510: ['french fries', 'chocolate'] => light mayo
# rule 1511: ['spaghetti', 'chocolate'] => cooking oil
# rule 1512: ['spaghetti', 'milk'] => oil
# rule 1513: ['spaghetti', 'chocolate'] => zucchini
# rule 1514: ['spaghetti', 'eggs'] => pancakes
# rule 1515: ['mineral water', 'milk'] => chutney
# rule 1516: ['spaghetti', 'milk'] => babies food
# rule 1517: ['spaghetti', 'milk'] => low fat yogurt
# rule 1518: ['chocolate', 'milk'] => almonds
# rule 1519: ['french fries', 'chocolate'] => milk
# rule 1520: ['mineral water', 'eggs'] => bacon
# rule 1521: ['burgers', 'eggs'] => cooking oil
# rule 1522: ['spaghetti', 'mineral water'] => extra dark chocolate
# rule 1523: ['spaghetti', 'mineral water'] => chocolate
# rule 1524: ['mineral water', 'chocolate'] => oil
# rule 1525: ['pancakes', 'mineral water'] => frozen vegetables
# rule 1526: ['burgers', 'eggs'] => french fries
# rule 1527: ['mineral water', 'eggs'] => gums
# rule 1528: ['mineral water', 'milk'] => cider
# rule 1529: ['mineral water', 'green tea'] => antioxydant juice
# rule 1530: ['frozen vegetables', 'mineral water'] => tomato juice
# rule 1531: ['mineral water', 'eggs'] => body spray
# rule 1532: ['french fries', 'chocolate'] => frozen smoothie
# rule 1533: ['frozen vegetables', 'mineral water'] => cider
# rule 1534: ['mineral water', 'green tea'] => meatballs
# rule 1535: ['frozen vegetables', 'mineral water'] => spaghetti
# rule 1536: ['spaghetti', 'eggs'] => tea
# rule 1537: ['milk', 'eggs'] => spaghetti
# rule 1538: ['spaghetti', 'frozen vegetables'] => cottage cheese
# rule 1539: ['mineral water', 'milk'] => clothes accessories
# rule 1540: ['spaghetti', 'eggs'] => tomato juice
# rule 1541: ['pancakes', 'spaghetti'] => fresh bread
# rule 1542: ['chocolate', 'eggs'] => pancakes
# rule 1543: ['frozen vegetables', 'mineral water'] => light cream
# rule 1544: ['chocolate', 'eggs'] => oil
# rule 1545: ['spaghetti', 'ground beef'] => zucchini
# rule 1546: ['frozen vegetables', 'mineral water'] => body spray
# rule 1547: ['pancakes', 'spaghetti'] => nonfat milk
# rule 1548: ['french fries', 'mineral water'] => mint
# rule 1549: ['spaghetti', 'mineral water'] => asparagus
# rule 1550: ['milk', 'eggs'] => avocado
# rule 1551: ['burgers', 'eggs'] => cider
# rule 1552: ['french fries', 'chocolate'] => cider
# rule 1553: ['spaghetti', 'green tea'] => strong cheese
# rule 1554: ['mineral water', 'ground beef'] => almonds
# rule 1555: ['green tea', 'eggs'] => eggplant
# rule 1556: ['green tea', 'eggs'] => salad
# rule 1557: ['spaghetti', 'milk'] => tomatoes
# rule 1558: ['burgers', 'eggs'] => clothes accessories
# rule 1559: ['pancakes', 'spaghetti'] => carrots
# rule 1560: ['spaghetti', 'french fries'] => burgers
# rule 1561: ['spaghetti', 'chocolate'] => milk
# rule 1562: ['olive oil', 'mineral water'] => black tea
# rule 1563: ['mineral water', 'chocolate'] => tomatoes
# rule 1564: ['spaghetti', 'eggs'] => grated cheese
# rule 1565: ['spaghetti', 'green tea'] => napkins
# rule 1566: ['olive oil', 'mineral water'] => tomatoes
# rule 1567: ['mineral water', 'eggs'] => protein bar
# rule 1568: ['mineral water', 'cake'] => mushroom cream sauce
# rule 1569: ['mineral water', 'ground beef'] => green beans
# rule 1570: ['burgers', 'eggs'] => energy bar
# rule 1571: ['mineral water', 'eggs'] => herb & pepper
# rule 1572: ['french fries', 'green tea'] => eggplant
# rule 1573: ['green tea', 'eggs'] => cauliflower
# rule 1574: ['spaghetti', 'milk'] => carrots
# rule 1575: ['french fries', 'mineral water'] => rice
# rule 1576: ['spaghetti', 'mineral water'] => light cream
# rule 1577: ['frozen vegetables', 'mineral water'] => cereals
# rule 1578: ['pancakes', 'spaghetti'] => low fat yogurt
# rule 1579: ['mineral water', 'green tea'] => gums
# rule 1580: ['milk', 'eggs'] => salad
# rule 1581: ['mineral water', 'chocolate'] => cereals
# rule 1582: ['mineral water', 'cake'] => chocolate bread
# rule 1583: ['frozen vegetables', 'mineral water'] => cottage cheese
# rule 1584: ['spaghetti', 'green tea'] => chicken
# rule 1585: ['mineral water', 'cake'] => whole wheat pasta
# rule 1586: ['spaghetti', 'french fries'] => cream
# rule 1587: ['mineral water', 'milk'] => oatmeal
# rule 1588: ['chocolate', 'eggs'] => shampoo
# rule 1589: ['olive oil', 'mineral water'] => spaghetti
# rule 1590: ['mineral water', 'green tea'] => chutney
# rule 1591: ['spaghetti', 'eggs'] => spinach
# rule 1592: ['milk', 'eggs'] => herb & pepper
# rule 1593: ['frozen vegetables', 'mineral water'] => tomato sauce
# rule 1594: ['spaghetti', 'mineral water'] => pancakes

# %% [markdown]
# It is difficult to asses whole result, but pure sets like mineral water and spagetti and products, that "are good with them" could be distinguished.
#
# Also it is important to undestrand, that number of sets depends greatly on $t$ и $a$.

# %%
Counter(list(map(lambda x: x[0][0], result))).most_common()
# Out:
# [(frozenset({'pancakes', 'spaghetti'}), 76),
#  (frozenset({'french fries', 'spaghetti'}), 74),
#  (frozenset({'frozen vegetables', 'spaghetti'}), 71),
#  (frozenset({'mineral water', 'spaghetti'}), 70),
#  (frozenset({'french fries', 'mineral water'}), 70),
#  (frozenset({'milk', 'spaghetti'}), 69),
#  (frozenset({'green tea', 'spaghetti'}), 69),
#  (frozenset({'chocolate', 'spaghetti'}), 68),
#  (frozenset({'frozen vegetables', 'mineral water'}), 67),
#  (frozenset({'mineral water', 'pancakes'}), 67),
#  (frozenset({'milk', 'mineral water'}), 65),
#  (frozenset({'mineral water', 'olive oil'}), 64),
#  (frozenset({'green tea', 'mineral water'}), 63),
#  (frozenset({'ground beef', 'spaghetti'}), 62),
#  (frozenset({'ground beef', 'mineral water'}), 60),
#  (frozenset({'eggs', 'mineral water'}), 59),
#  (frozenset({'eggs', 'spaghetti'}), 58),
#  (frozenset({'chocolate', 'milk'}), 58),
#  (frozenset({'french fries', 'green tea'}), 54),
#  (frozenset({'eggs', 'milk'}), 54),
#  (frozenset({'cake', 'mineral water'}), 53),
#  (frozenset({'chocolate', 'mineral water'}), 50),
#  (frozenset({'chocolate', 'french fries'}), 46),
#  (frozenset({'chocolate', 'eggs'}), 46),
#  (frozenset({'eggs', 'green tea'}), 38),
#  (frozenset({'burgers', 'eggs'}), 33),
#  (frozenset({'eggs', 'french fries'}), 31)]
